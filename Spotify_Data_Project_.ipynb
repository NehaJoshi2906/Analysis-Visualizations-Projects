# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df_tracks  = pd.read_csv('/content/SpotifyFeatures.csv')

# %%
df_tracks.head(5)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
# checking if null values are present 
pd.isnull(df_tracks).sum()
  # sum function to check the total no of null values present for  each of thre column
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
# to check total no of ows and columns as well as their respective data types 
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232725 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
# ...

# %%
# to find the 10 leat popular songs from the datasets
sorted_df=df_tracks.sort_values('popularity', ascending = True).head(10)
sorted_df

#we have used the sort_values function to sorth the values ; we have used the ascending function which will sort the songs acc to popularity in ascending oreder
# so the first 10 songs with min popularity can be obtained
# Out:
#                   genre             artist_name  \
# 0                 Movie          Henri Salvador
# 74954  Children's Music             Sing n Play
# 74958  Children's Music  Children Songs Company
# 74959  Children's Music  Children Songs Company
# 74961  Children's Music  Children Songs Company
# 74962  Children's Music  Children Songs Company
# 74963  Children's Music  Children Songs Company
# 74964  Children's Music             Sing n Play
# 56153             Movie         Bruno Pelletier
# 74966  Children's Music  Children Songs Company
#
#                                track_name                track_id  popularity  \
# 0             C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV           0
# 74954                See, See My Playmate  3WaCwwpGoxLEkFmd6cpZO5           0
# 74958           By the God - Instrumental  5yDehr9ccZo3vBO8hZXFcK           0
# 74959  Interruption Please - Instrumental  6NEULw7AmTOAYRunPWcFvn           0
# ...

# %%
#checking some descreptive  stats related to the data
df_tracks.describe().transpose ()
# Out:
#                      count           mean            std          min  \
# popularity        232725.0      41.127502      18.189948      0.00000
# acousticness      232725.0       0.368560       0.354768      0.00000
# danceability      232725.0       0.554364       0.185608      0.05690
# duration_ms       232725.0  235122.339306  118935.909299  15387.00000
# energy            232725.0       0.570958       0.263456      0.00002
# instrumentalness  232725.0       0.148301       0.302768      0.00000
# liveness          232725.0       0.215009       0.198273      0.00967
# loudness          232725.0      -9.569885       5.998204    -52.45700
# speechiness       232725.0       0.120765       0.185518      0.02220
# tempo             232725.0     117.666585      30.898907     30.37900
# valence           232725.0       0.454917       0.260065      0.00000
#
#                           25%            50%          75%          max
# ...

# %%
# checking for the top songs with popularity greater then 90
most_popular=df_tracks.query('popularity>90' , inplace = False).sort_values('popularity',ascending = False)
most_popular[:10]
#[:10] as we did not use the .head(10) in the function 
# query is a function in pd a condition greater then 90inplace=false as we dont want to change the orirginal dataframe,
# we use the sort the valyes as we want to sort the values according to that popularity and now in descending order
# Out:
#             genre    artist_name  \
# 107804        Pop  Ariana Grande
# 9027        Dance  Ariana Grande
# 9026        Dance  Ariana Grande
# 86951         Rap    Post Malone
# 107803        Pop    Post Malone
# 107802        Pop  Ariana Grande
# 138918  Reggaeton   Daddy Yankee
# 66643     Hip-Hop   Daddy Yankee
# 107909        Pop   Daddy Yankee
# 86953         Rap    Post Malone
#
#                                            track_name                track_id  \
# 107804                                        7 rings  14msK75pk3pA33pzPVNtBF
# 9027                                          7 rings  14msK75pk3pA33pzPVNtBF
# 9026         break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 86951                                            Wow.  6MWtB6iiXyIwun0YzU6DFP
# 107803                                           Wow.  6MWtB6iiXyIwun0YzU6DFP
# 107802       break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# ...

# %%
# using the lambda function and dividing the values by 1000 so that the values are converted into just seconds 
#inplace as true to make required changes into our original data frame too

# %%
df_tracks
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
# first visualization:creating the correlation map
# we are gonna drop three columns ie:key,explicit and mode and apply pearson correlation method then we use heatmap function from seaborn 
#to get the required correlation map
#where as annot is annotation value is true which will write the data value in ecah cell 
#fmt =1g is the sting formatting tool while adding annotataions,
#vmin and vmax are the values set to anchor the colour map 
#cmap="infereno" stands for colour map where as the infereno is the colur palette used 
# then we set the title for the map and then the required labels 

corr_df =df_tracks.drop(["key","mode"],axis=1 ).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(corr_df,annot=True,fmt=".1g", vmin=1 ,vmax=1 ,center=0, cmap="inferno", linewidths =1 , linecolor="Black")
heatmap.set_title("correlation hetmap between variables ")
heatmap.set_xticklabels(heatmap.get_xticklabels()  , rotation =90)

#minus value indicates they have negative correlation ; like energy and acoustiness has high negative correlation 
#means if energy is high the acoustiness is very low where as danceability and valence have positive cotrelation.
# Out:
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'acousticness'),
#  Text(2.5, 0, 'danceability'),
#  Text(3.5, 0, 'duration_ms'),
#  Text(4.5, 0, 'energy'),
#  Text(5.5, 0, 'instrumentalness'),
#  Text(6.5, 0, 'liveness'),
#  Text(7.5, 0, 'loudness'),
#  Text(8.5, 0, 'speechiness'),
#  Text(9.5, 0, 'tempo'),
#  Text(10.5, 0, 'valence')]

# %%
# we will sample aour data and take only 4% of the total data and create two regression plotes using this data
sample_df=df_tracks.sample(int(0.004*len(df_tracks)))

# %%
print(len(sample_df))
# Out:
# 930

# %%
# we will plot the regression plots now ,we will plot it between loudness and energy as it has positive correlation as obserevd from the correlation graph
#we are using the function called regplot from the seaborn package 
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y ="loudness",x ="energy",color="c").set(title = "Loudness vs Energy")

# as we can see all the points follow the same direction and the direction of line is also in one direction gradually increasing which indicates positive corrrelation
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy')]

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df,y ="popularity",x ="acousticness",color="c").set(title = "Loudness vs Energy")
#as we can see hte line going downward later we can see the negative correlation as popularity increase acousticness decreases
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy')]

# %%
df_tracks.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
#we are creating the distribution plots to know the distribution of songs per month 
#so we use the diplot function for creating the plot,
time_signature=df_tracks.time_signature
sns.displot(time_signature,discrete =True,aspect=2,height=5,kind="hist").set(title="no of songs acc to time ")

# %%
# to see the duration of the songs over the time so we are gonna create the power plot
total_duration=df_tracks.duration_ms
time_signature=df_tracks.time_signature
fig_dimensions=(18,7)
fig, ax =plt.subplots(figsize=fig_dimensions)
fig=sns.barplot(x=time_signature,y=total_duration,ax =ax,errwidth = False ).set(title="Duration over the time")

# %%
# to see duration of songs acc to different genre
plt.title("duration of songs acc to different genre")
sns.color_palette( "rocket" , as_cmap =True)
sns.barplot(y ="genre", x ="duration_ms", data =df_tracks)
plt.xlabel("duration of songs")
plt.ylabel("Genre")
# Out:
# Text(0, 0.5, 'Genre')

# %%
# to find genre by popularity
sns.set_style(style="darkgrid")
plt.figure(figsize=(10,6))
famous=df_tracks.sort_values("popularity"  ,ascending =False ).head(10)
sns.barplot(y="genre",x="popularity",data=famous).set(title="top 5 genre by popularity")
# we took .head(10) instead of 5 just for top 5 as there are few genre which are repetative as we have children appearing twice in our duaration map
# Out:
# [Text(0.5, 1.0, 'top 5 genre by popularity')]

# %%
df_tracks.head(2)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910               0.0  C#     0.346    -1.828  Major
# 1       137373   0.737               0.0  F#     0.151    -5.559  Minor
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816

# %%
#to see popularity  of songs acc to  duration of songs 
plt.title("duration of songs acc to different genre")
sns.color_palette( "rocket" , as_cmap =True)
sns.barplot(y ="popularity", x ="duration_ms", data =df_tracks)
plt.xlabel("duration of songs")
plt.ylabel("Genre")
# Out:
# Text(0, 0.5, 'Genre')

# %%
# to see which are the top 5 artists

sns.set_style(style="darkgrid")
plt.figure(figsize=(10,6))
famous=df_tracks.sort_values("popularity"  ,ascending =False ).head(10)
sns.barplot(y="artist_name",x="popularity",data=famous).set(title="top 10 artists by popularity")

# we have only 4 artists as according to popularity these artists were repetative
# Out:
# [Text(0.5, 1.0, 'top 10 artists by popularity')]
